# %%
# Define the tree structure as an adjacency list
tree = {
    'S': ['1'],
    '1': ['2'],
    '2': ['3'],
    '3': ['4', '5'],
    '5': ['6', '7', '8'],
    '6': ['9'],
    '9': ['11'],
    '11': ['13'],
    '13': ['15', '17'],
    '15': ['18'],
    '18': ['20', '21'],
    '20': ['22'],
    '21': ['23'],
    '8': ['10'],
    '10': ['12'],
    '12': ['14'],
    '14': ['16'],
    '16': ['19'],
    '19': ['G'],
}

# Create a set to keep track of visited nodes
visited = set()

# Depth-First Search (DFS)
def bfs(graph, start, goal):
    queue = [start]
    while queue:
        node = queue.pop(0)
        if node == goal:
            print(node)
            visited.add(node)
            break  # Exit the loop when the goal node is found
        if node not in visited:
            print(node)
            visited.add(node)
            queue.extend(neighbor for neighbor in graph.get(node, []) if neighbor not in visited)


def bfs(graph, start, goal):
    queue = [start]
    while queue:
        node = queue.pop(0)
        if node == goal:
            print(node)
            visited.add(node)
            break  # Exit the loop when the goal node is found
        if node not in visited:
            print(node)
            visited.add(node)
            queue.extend(neighbor for neighbor in graph.get(node, []) if neighbor not in visited)


# Define the starting and goal nodes
start_node = 'S'
goal_node = 'G'

# Perform DFS and BFS starting from the root node 'S'
print("Depth-First Search (DFS):")
dfs(tree, start_node, goal_node)

# Reset the visited set for BFS
visited = set()

print("\nBreadth-First Search (BFS):")
bfs(tree, start_node, goal_node)
# Out:
# Depth-First Search (DFS):
# S
# 1
# 2
# 3
# 4
# 5
# 6
# 9
# 11
# 13
# 15
# 18
# 20
# 22
# 21
# 23
# 17
# 7
# 8
# 10
# 12
# 14
# 16
# 19
# G
#
# Breadth-First Search (BFS):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\clari\Documents\GitHub\ArtificialIntelligence\Week2\exercise2.ipynb Cell 1 in <cell line: 61>()
#      <a href='vscode-notebook-cell:/c%3A/Users/clari/Documents/GitHub/ArtificialIntelligence/Week2/exercise2.ipynb#W0sZmlsZQ%3D%3D?line=57'>58</a> visited = set()
#      <a href='vscode-notebook-cell:/c%3A/Users/clari/Documents/GitHub/ArtificialIntelligence/Week2/exercise2.ipynb#W0sZmlsZQ%3D%3D?line=59'>60</a> print("\nBreadth-First Search (BFS):")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/clari/Documents/GitHub/ArtificialIntelligence/Week2/exercise2.ipynb#W0sZmlsZQ%3D%3D?line=60'>61</a> bfs(tree, start_node)
#
# ...
